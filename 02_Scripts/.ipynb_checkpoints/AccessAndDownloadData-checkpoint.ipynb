# %% [markdown]
# # Graphing Elevation Profile with ArcGIS Python API

# %% [markdown]
# Contributors: Jia-Shen Tsai, Wendy Wen, Zhengqi Jiao, Miaojun Pang,
# Alexander Yoshizumi
#
# Last Updated: 2023-12-10
#
# Description: When run, script downoad the data and

# %%
#import library
from arcgis import GIS
from arcgis.features import FeatureLayer, FeatureSet, GeoAccessor
from arcgis.features import elevation as elev                       #Link to elevation tools

# Authenticate with your ArcGIS Online or ArcGIS Enterprise account
gis = GIS('home')

# %%
# #call the latest data (failed because the layers from FeatureService is puzzling)
# tracksLayer = FeatureLayer("https://geo.dot.gov/server/rest/services/Hosted/Amtrak_Routes_DS/FeatureServer/0/query?outFields=*&where=1%3D1")
# sdf_route = GeoAccessor.from_layer(routeAll)

# %%
# results = gis.content.search(query='Amtrak Routes owner:USDOT_BTS',
#                             outside_org=True)
# results

# %%
# tracksItem = results[0]
# type(tracksItem)

# %%
# tracksLayer = tracksItem.layers[0]

# %%
# type(tracksLayer)

# %%
# print([fld.name for fld in tracksLayer.properties.fields])

# %%
# fset_Carolinian = tracksLayer.query(where="name='Carolinian'")

# %%
# another way to read the data: read the data from local
sdf_tracks = GeoAccessor.from_featureclass('../01_Data/01_Source/Amtrak_Routes/amtrak_routes_ds_amtrak_june_18_2019.shp')

# %%
sdf_tracks.head()
# Out:
#    FID  objectid               name    shape_leng    shape_le_1  shape_Le_2  \
# 0    0         1              Acela  7.410105e+05  7.410105e+05    7.895401
# 1    1         2         Adirondack  6.156754e+05  6.156754e+05    6.013791
# 2    2         3         Auto Train  1.474024e+06  1.474024e+06   14.082956
# 3    3         4         Blue Water  5.114384e+05  5.114384e+05    5.834930
# 4    4         5  California Zephyr  4.313889e+06  4.313889e+06   47.246098
#
#                                                SHAPE
# 0  {"paths": [[[-77.01421481299997, 38.8836032980...
# 1  {"paths": [[[-73.74197248699994, 42.6402762260...
# 2  {"paths": [[[-81.31769915799998, 28.7589285180...
# 3  {"paths": [[[-87.63610084199996, 41.8177249360...
# 4  {"paths": [[[-108.55590727399999, 39.062632268...

# %%
#Subset one line to do the calculation
fset_Carolinian = sdf_tracks.query('name == "Carolinian"')
len(fset_Carolinian)
# Out:
# 1

# %%
#IF I use the feature layer found by searching online is content, it'll be feature set
#If directly read in with GeoAccessor , it'll be df
#both formats could work in the following elev.profile function
type(fset_Carolinian)
# Out:
# pandas.core.frame.DataFrame

# %%
#Compute the profile with fset_Carolinian
profile_fset = elev.profile(
    input_line_features = fset_Carolinian,
    dem_resolution = '30m',
    maximum_sample_distance = 1000,
    maximum_sample_distance_units = 'Meters'
)

# %%
type(profile_fset)
# Out:
# arcgis.features.feature.FeatureSet

# %%
profile_sdf = profile_fset.sdf
profile_sdf
# Out:
#    OBJECTID DEMResolution   ProductName Source            Source_URL  \
# 0         1           30m  NED_1_arcsec   USGS  http://ned.usgs.gov/
#
#    ProfileLength  Shape_Length  \
# 0  869868.797056      8.745682
#
#                                                SHAPE
# 0  {"paths": [[[-78.2593484776275, 35.54109777395...

# %%
elev_summary = elev.summarize_elevation(
    input_features = fset_Carolinian,
    dem_resolution = '30m',
    include_slope_aspect = True
)

# %%
type(elev_summary)
# Out:
# arcgis.features.feature.FeatureSet

# %%
elev_summary_sdf = elev_summary.sdf
elev_summary_sdf
# Out:
#    FID        name  shape_leng     shape_le_1  shape_Le_2  ID  MinElevation  \
# 0    1  Carolinian         0.0  871554.626039    8.745682   1     -4.464453
#
#    MeanElevation  MaxElevation  MinSlope  MeanSlope   MaxSlope  MeanAspect  \
# 0       30.67496    122.447281       0.0   2.074866  24.175549  138.785329
#
#   DEMResolution   ProductName Source            Source_URL  Shape_Length  \
# 0           30m  NED_1_arcsec   USGS  http://ned.usgs.gov/      8.745682
#
#                                                SHAPE
# 0  {"paths": [[[-78.25934847733839, 35.5410977735...

# %% [markdown]
# # Clipping NC Routes Out with arcpy

# %%
import arcpy

# %%
#pip install geopandas
#pip install contextily
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx

# %%
# Set workspace
arcpy.env.workspace = "../01_Data/01_Source/"
arcpy.env.overwriteOutput = True

# %%
# Input polyline feature class
input_fc = "Amtrak_Routes/amtrak_routes_ds_amtrak_june_18_2019.shp"
output_fc = "../01_Data/02_Processed/Amtrak_Route_NC.shp"
nc_boundary = "NC_Boundary/NCDOT_State_Boundary.shp"

# %%
arcpy.analysis.Clip(input_fc, nc_boundary, output_fc)
# Out:
# <Result '..\\01_Data\\02_Processed\\Amtrak_Route_NC.shp'>

# %%
nc_tracks_gdf = gpd.read_file("../01_Data/02_Processed/Amtrak_Route_NC.shp")

# %%
nc_tracks_gdf.crs.to_string()
# Out:
# 'EPSG:4326'

# %%
route_plot = nc_tracks_gdf.to_crs(3857).plot()
ctx.add_basemap(route_plot)

# %%
nc_tracks_gdf.head()
# Out:
#    objectid                     name    shape_leng    shape_le_1  shape_Le_2  \
# 0         3               Auto Train  1.474024e+06  1.474024e+06   14.082956
# 1        31  Silver_Service/Palmetto  2.984346e+06  2.984346e+06   29.026557
# 2        37                 Crescent  2.230998e+06  2.230998e+06   22.651323
# 3        46               Carolinian  0.000000e+00  8.715546e+05    8.745682
# 4        47                 Piedmont  0.000000e+00  2.882651e+05    2.980784
#
#                                             geometry
# 0  MULTILINESTRING ((-79.31281 34.50569, -79.3128...
# 1  MULTILINESTRING ((-79.31281 34.50569, -79.3128...
# 2  MULTILINESTRING ((-81.45065 35.16823, -81.4499...
# 3  MULTILINESTRING ((-78.25935 35.54110, -78.2566...
# 4  MULTILINESTRING ((-80.82749 35.23796, -80.8273...

# %%
mask = (nc_tracks_gdf["name"] == 'Carolinian')
carolinian_gdf = nc_tracks_gdf[mask]
type(carolinian_gdf)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# ## download the carolinian route in NC as a shp

# %%
carolinian_sdf = GeoAccessor.from_geodataframe(carolinian_gdf)

# %%
carolinian_item = carolinian_sdf.spatial.to_featurelayer()

# %%
carolinian_shp = carolinian_item.export(title='carolinian', export_format='Shapefile')

# %%
carolinian_shp.download("../01_Data/02_Processed")

# %%
carolinian_fl = carolinian_item.layers[0]

# %% [markdown]
# # Drawing profile with arcpy 3D tool

# %%
input_fl = "../01_Data/02_Processed/carolinian.shp"
profile_tg = "NC_DEM.tiff"
output_tbl = "../01_Data/02_Processed/CarolinianProfile.csv"
graphName = "Carolinian Profile Graph"                         #The output graph is not supported in Pro (sad)

# %%
#using 3D Analyst toolbox to create the stack profile
#Documentation: https://pro.arcgis.com/en/pro-app/latest/tool-reference/3d-analyst/stack-profile.htm
arcpy.ddd.StackProfile(
    input_fl,
    profile_tg,
    output_tbl,
    graphName
)

# %% [markdown]
# # Access Amtrak Stations

# %%
stationItem = gis.content.get("6ad5c20bbc44441cb7777c83928dc0c0")
station_fl = stationItem.layers[0]

# %%
print([fld.name for fld in station_fl.properties.fields])
# Out:
# ['FID', 'objectid_1', 'OBJECTID', 'statype', 'stntype', 'zipcode', 'STATE', 'city', 'address2', 'address1', 'name', 'code', 'stationnam']

# %%
print(station_fl.get_unique_values('STATE'))
# Out:
# ['TX', 'KS', 'WI', 'PA', 'DE', 'IN', 'IL', 'NH', 'BC', 'MD', 'CO', 'DC', 'MI', 'VA', 'ME', 'SC', 'RI', 'WA', 'MA', 'NV', 'NY', 'OH', 'CT', 'LA', 'MO', 'NJ', 'CA', 'OR', 'MN', 'MT', 'OK', 'ON', 'FL', 'AR', 'IA', 'VT', 'AL', 'ND', 'ID', 'GA', 'AZ', 'MS', 'TN', 'NC', 'NE', 'WV', 'WY', 'QC', 'NM', 'KY', 'UT']

# %%
#Subset records that are in NC
NCStation_fs = station_fl.query(where="STATE = 'NC'")
type(NCStation_fs)

#Display the number of results returned
len(NCStation_fs)
# Out:
# 29

# %%
#Map the feature set with 'draw'
map2 = gis.map('North Carolina')
map2.basemap = 'osm'
map2.draw(NCStation_fs, popup={'title':'stationnam','content':'code'})
map2.zoom=8
map2
# Out:
# MapView(layout=Layout(height='400px', width='100%'))
# <div class="map-static-img-preview-2c0b0188-f0bc-4d76-862d-77daad197fe3"><img src=""></img></div>
# <div class="map-html-embed-preview-2c0b0188-f0bc-4d76-862d-77daad197fe3"></div>

# %% [markdown]
# # Read all json data

# %%
import pandas as pd

# %%
df = pd.read_json('../01_Data/01_Source/ASM/2023_11_12_14_45_11_107617.json')

# %%
df.head()
# Out:
#               train_id railroad origin_date  number all_numbers  \
# 0  2023-11-12_AMTK_572   AMTRAK  2023-11-12     572       [572]
# 1  2023-11-12_AMTK_573   AMTRAK  2023-11-12     573       [573]
# 2  2023-11-12_AMTK_615   AMTRAK  2023-11-12     615       [615]
# 3  2023-11-12_AMTK_665   AMTRAK  2023-11-12     665       [665]
# 4  2023-11-12_AMTK_670   AMTRAK  2023-11-12     670       [670]
#
#                 name origin destination  partial_train  last_updated  \
# 0  Pacific Surfliner    LAX         SAN          False    1699818141
# 1  Pacific Surfliner    SAN         LAX          False    1699818125
# 2           Keystone    PHL         HAR          False    1699818139
# 3           Keystone    NYP         HAR          False    1699817131
# 4           Keystone    HAR         NYP          False    1699818138
#
#       current_timezone  threshold  disruption  total_miles  \
# 0  America/Los_Angeles         10       False          128
# 1  America/Los_Angeles         10       False          128
# 2     America/New_York         10       False          104
# 3     America/New_York         10       False          195
# 4     America/New_York         10       False          195
#
#                                             location  \
# 0  {'latitude': 33.868531, 'longitude': -117.9307...
# 1  {'latitude': 33.546865, 'longitude': -117.6743...
# 2  {'latitude': 39.986447, 'longitude': -75.81912...
# 3  {'latitude': 39.960709, 'longitude': -75.18253...
# 4  {'latitude': 40.053681, 'longitude': -76.29986...
#
#                                                stops
# 0  [{'code': 'LAX', 'miles': 0, 'sched_depart': 1...
# 1  [{'code': 'SAN', 'miles': 0, 'sched_depart': 1...
# 2  [{'code': 'PHL', 'miles': 0, 'sched_depart': 1...
# 3  [{'code': 'NYP', 'miles': 0, 'sched_depart': 1...
# 4  [{'code': 'HAR', 'miles': 0, 'sched_depart': 1...

# %%
for i in df['location']:
    print(i)
# Out:
# {'latitude': 33.868531, 'longitude': -117.930745, 'heading': 90, 'speed': 54.76}
# {'latitude': 33.546865, 'longitude': -117.674313, 'heading': 0, 'speed': 70.05}
# {'latitude': 39.986447, 'longitude': -75.819124, 'heading': 370, 'speed': 27.16}
# {'latitude': 39.960709, 'longitude': -75.182535, 'heading': 135, 'speed': 16.05}
# {'latitude': 40.053681, 'longitude': -76.299868, 'heading': 90, 'speed': 50.84}
# {'latitude': 40.75948, 'longitude': -74.079629, 'heading': 45, 'speed': 88.44}
# {'latitude': 42.207929, 'longitude': -72.097489, 'heading': 370, 'speed': 57.81}
# {'latitude': 45.426283, 'longitude': -122.577857, 'heading': 90, 'speed': 53.33}
# {'latitude': 47.476895999999996, 'longitude': -122.252815, 'heading': 315, 'speed': 52.64}
# {'latitude': 49.204706, 'longitude': -122.887215, 'heading': 0, 'speed': 11.0}
# {'latitude': 47.790907, 'longitude': -122.390915, 'heading': 180, 'speed': 33.67}
# {'latitude': 42.814084, 'longitude': -73.942827, 'heading': 225, 'speed': 5.02}
# {'latitude': 38.548389, 'longitude': -90.526122, 'heading': 90, 'speed': 55.66}
# {'latitude': 39.277965, 'longitude': -89.890257, 'heading': 225, 'speed': 0.0}
# {'latitude': 42.232079, 'longitude': -87.878637, 'heading': 0, 'speed': 41.93}
# {'latitude': 42.581639, 'longitude': -87.905035, 'heading': 180, 'speed': 78.22}
# {'latitude': 44.1573, 'longitude': -77.4542, 'heading': 250, 'speed': 92.58}
# {'latitude': 42.6751, 'longitude': -81.8071, 'heading': 225, 'speed': 54.68}
# {'latitude': 42.4646, 'longitude': -82.0897, 'heading': 44, 'speed': 65.24}
# {'latitude': 45.0422, 'longitude': -74.8617, 'heading': 269, 'speed': 76.43}
# {'latitude': 44.3207, 'longitude': -76.356, 'heading': 257, 'speed': 30.45}
# {'latitude': 44.4302, 'longitude': -75.973, 'heading': 45, 'speed': 69.59}
# {'latitude': 41.691349, 'longitude': -87.507467, 'heading': 315, 'speed': 0.06}
# {'latitude': 45.3182, 'longitude': -75.135, 'heading': 94, 'speed': 94.45}
# {'latitude': 46.2125, 'longitude': -72.1406, 'heading': 59, 'speed': 34.8}
# {'latitude': 43.6462, 'longitude': -79.3715, 'heading': 253, 'speed': 15.53}
# {'latitude': 44.211, 'longitude': -76.7972, 'heading': 82, 'speed': 82.64}
# {'latitude': 44.9067, 'longitude': -76.0187, 'heading': 309, 'speed': 13.05}
# {'latitude': 44.2933, 'longitude': -76.4325, 'heading': None, 'speed': 0.0}
# {'latitude': 43.7315, 'longitude': -79.2446, 'heading': 220, 'speed': 83.26}
# {'latitude': 43.8581, 'longitude': -78.9968, 'heading': 72, 'speed': 93.21}
# {'latitude': 45.4165, 'longitude': -75.6431, 'heading': 263, 'speed': 19.26}
# {'latitude': 45.8986, 'longitude': -72.4638, 'heading': 237, 'speed': 48.47}
# {'latitude': 39.933739, 'longitude': -88.270048, 'heading': 180, 'speed': 79.13}
# {'latitude': 45.7043, 'longitude': -64.2422, 'heading': 19, 'speed': 47.85}
# {'latitude': 45.3495, 'longitude': -80.0379, 'heading': 0, 'speed': 0.0}
# {'latitude': 54.5435, 'longitude': -128.5026, 'heading': 67, 'speed': 0.0}
# {'latitude': 41.300351, 'longitude': -72.377801, 'heading': 45, 'speed': 0.0}
# {'latitude': 41.247212, 'longitude': -72.997529, 'heading': 45, 'speed': 66.84}
# {'latitude': 41.300378, 'longitude': -72.377725, 'heading': 45, 'speed': 0.0}
# {'latitude': 38.899651, 'longitude': -77.004786, 'heading': 180, 'speed': 3.93}
# {'latitude': 39.964291, 'longitude': -75.185335, 'heading': 315, 'speed': 40.96}
# {'latitude': 41.384938, 'longitude': -71.79078, 'heading': 225, 'speed': 0.0}
# {'latitude': 41.859418, 'longitude': -71.406281, 'heading': 180, 'speed': 68.07}
# {'latitude': 41.29654, 'longitude': -72.387345, 'heading': 0, 'speed': 0.0}
# {'latitude': 40.977638999999996, 'longitude': -73.696573, 'heading': 0, 'speed': 26.0}
# {'latitude': 41.358308, 'longitude': -72.068131, 'heading': 225, 'speed': 0.0}
# {'latitude': 39.302738, 'longitude': -76.635844, 'heading': 180, 'speed': 15.5}
# {'latitude': 39.974549, 'longitude': -75.196733, 'heading': 180, 'speed': 28.5}
# {'latitude': 41.764409, 'longitude': -73.943269, 'heading': 135, 'speed': 84.24}
# {'latitude': 40.021634, 'longitude': -75.613878, 'heading': 90, 'speed': 35.74}
# {'latitude': 40.153878, 'longitude': -76.6421, 'heading': 370, 'speed': 70.11}
# {'latitude': 42.020394, 'longitude': -72.599481, 'heading': 0, 'speed': 49.46}
# {'latitude': 42.234361, 'longitude': -72.625611, 'heading': 180, 'speed': 40.36}
# {'latitude': 38.061989, 'longitude': -78.65047, 'heading': 370, 'speed': 58.76}
# {'latitude': 43.13326, 'longitude': -77.725642, 'heading': 225, 'speed': 37.27}
# {'latitude': 43.066327, 'longitude': -76.531565, 'heading': 45, 'speed': 78.82}
# {'latitude': 27.547668, 'longitude': -81.468929, 'heading': 135, 'speed': 21.28}
# {'latitude': 38.804894, 'longitude': -77.075823, 'heading': 90, 'speed': 38.83}
# {'latitude': 28.002901, 'longitude': -81.734729, 'heading': 180, 'speed': 0.05}
# {'latitude': 44.957258, 'longitude': -73.39467, 'heading': 225, 'speed': 59.86}
# {'latitude': 43.901799, 'longitude': -73.401788, 'heading': 315, 'speed': 48.57}
# {'latitude': 36.792808, 'longitude': -77.470385, 'heading': 180, 'speed': 76.58}
# {'latitude': 37.714577, 'longitude': -77.494975, 'heading': 0, 'speed': 68.98}
# {'latitude': 35.439048, 'longitude': -80.60831, 'heading': 0, 'speed': 75.62}
# {'latitude': 36.089347, 'longitude': -79.691852, 'heading': 225, 'speed': 51.49}
# {'latitude': 41.360551, 'longitude': -72.071999, 'heading': 315, 'speed': 0.01}
# {'latitude': 40.756829, 'longitude': -74.085481, 'heading': 45, 'speed': 51.15}
# {'latitude': 35.867607, 'longitude': -77.828211, 'heading': 225, 'speed': 69.97}
# {'latitude': 39.416039, 'longitude': -76.29249, 'heading': 45, 'speed': 121.87}
# {'latitude': 35.873291, 'longitude': -77.825137, 'heading': 45, 'speed': 70.18}
# {'latitude': 39.527577, 'longitude': -76.129786, 'heading': 225, 'speed': 108.75}
# {'latitude': 27.484475, 'longitude': -81.349765, 'heading': 370, 'speed': 81.04}
# {'latitude': 28.975221, 'longitude': -81.33221, 'heading': 0, 'speed': 52.99}
# {'latitude': 39.955357, 'longitude': -75.182428, 'heading': 180, 'speed': 0.0}
# {'latitude': 38.981808, 'longitude': -76.826845, 'heading': 225, 'speed': 123.55}
# {'latitude': 41.485993, 'longitude': -71.557954, 'heading': 225, 'speed': 17.63}
# {'latitude': 39.737191, 'longitude': -75.55134, 'heading': 315, 'speed': 0.0}
# {'latitude': 40.067429, 'longitude': -74.961595, 'heading': 45, 'speed': 101.44}
# {'latitude': 37.539097, 'longitude': -77.491793, 'heading': 225, 'speed': 37.78}
# {'latitude': 41.385041, 'longitude': -71.790345, 'heading': 370, 'speed': 0.03}
# {'latitude': 37.252689, 'longitude': -77.42261, 'heading': 45, 'speed': 45.89}
# {'latitude': 41.340958, 'longitude': -72.099702, 'heading': 0, 'speed': 0.0}
# {'latitude': 40.686768, 'longitude': -74.201402, 'heading': 225, 'speed': 48.68}
# {'latitude': 40.87077, 'longitude': -73.812318, 'heading': 45, 'speed': 57.74}
# {'latitude': 38.916744, 'longitude': -76.917948, 'heading': 90, 'speed': 103.49}
# {'latitude': 39.307495, 'longitude': -76.614451, 'heading': 370, 'speed': 3.06}
# {'latitude': 41.481438, 'longitude': -89.234129, 'heading': 45, 'speed': 78.86}
# {'latitude': 39.179525, 'longitude': -120.858412, 'heading': 225, 'speed': 30.81}
# {'latitude': 41.832138, 'longitude': -87.798582, 'heading': 90, 'speed': 0.0}
# {'latitude': 47.661436, 'longitude': -122.393219, 'heading': 135, 'speed': 31.29}
# {'latitude': 30.145835, 'longitude': -94.678115, 'heading': 90, 'speed': 58.07}
# {'latitude': 43.693169, 'longitude': -89.8665, 'heading': 135, 'speed': 78.09}
# {'latitude': 51.4346, 'longitude': -104.8139, 'heading': 120, 'speed': 17.4}
# {'latitude': 39.063635, 'longitude': -108.569713, 'heading': 135, 'speed': 0.12}
# {'latitude': 48.142727, 'longitude': -103.620914, 'heading': 370, 'speed': 0.09}
# {'latitude': 48.556968, 'longitude': -110.437009, 'heading': 90, 'speed': 80.38}
# {'latitude': 31.446445, 'longitude': -106.089411, 'heading': 315, 'speed': 0.0}
# {'latitude': 35.390726, 'longitude': -105.265513, 'heading': 370, 'speed': 49.89}
# {'latitude': 35.082285, 'longitude': -106.647509, 'heading': 0, 'speed': 0.0}
# {'latitude': 43.730615, 'longitude': -122.375312, 'heading': 370, 'speed': 31.61}
# {'latitude': 37.594533, 'longitude': -122.07221, 'heading': 135, 'speed': 0.0}
# {'latitude': 32.749216, 'longitude': -97.323601, 'heading': 135, 'speed': 0.09}
# {'latitude': 41.315209, 'longitude': -88.143431, 'heading': 45, 'speed': 66.86}
# {'latitude': 33.159064, 'longitude': -87.305066, 'heading': 225, 'speed': 57.49}
# {'latitude': 39.197308, 'longitude': -76.696665, 'heading': 0, 'speed': 49.31}
# {'latitude': 38.749925, 'longitude': -121.285711, 'heading': 45, 'speed': 0.0}
# {'latitude': 34.314195, 'longitude': -119.361112, 'heading': 315, 'speed': 35.62}
# {'latitude': 42.65442, 'longitude': -73.741998, 'heading': 135, 'speed': 17.99}
# {'latitude': 46.715894, 'longitude': -122.953414, 'heading': 180, 'speed': 0.07}
# {'latitude': 32.541784, 'longitude': -97.367088, 'heading': 0, 'speed': 78.06}
# {'latitude': 38.144516, 'longitude': -79.05585, 'heading': 90, 'speed': 44.96}
# {'latitude': 40.729821, 'longitude': -74.169115, 'heading': 225, 'speed': 24.67}
# {'latitude': 32.367304, 'longitude': -88.688802, 'heading': 45, 'speed': 24.01}
# {'latitude': 31.242266, 'longitude': -90.450613, 'heading': 180, 'speed': 13.33}
# {'latitude': 47.9696, 'longitude': -72.1673, 'heading': 156, 'speed': 32.93}
# nan
# {'latitude': 43.315759, 'longitude': -70.684037, 'heading': 370, 'speed': 75.17}
# {'latitude': 43.64853, 'longitude': -70.280083, 'heading': 180, 'speed': 13.94}
# {'latitude': 35.37148, 'longitude': -119.042737, 'heading': 90, 'speed': 59.24}
# {'latitude': 36.759515, 'longitude': -119.787351, 'heading': 135, 'speed': 33.39}
# {'latitude': 37.800615, 'longitude': -121.001783, 'heading': 135, 'speed': 67.0}
# {'latitude': 37.452176, 'longitude': -120.70371, 'heading': 315, 'speed': 30.39}
# {'latitude': 37.798364, 'longitude': -122.284712, 'heading': 370, 'speed': 20.52}
# {'latitude': 50.021, 'longitude': -98.5205, 'heading': 289, 'speed': 59.03}
# {'latitude': 37.874715, 'longitude': -122.303411, 'heading': 0, 'speed': 44.12}
# {'latitude': 37.405297, 'longitude': -121.965971, 'heading': 135, 'speed': 26.83}
# {'latitude': 38.587957, 'longitude': -121.52078, 'heading': 90, 'speed': 18.58}
# {'latitude': 38.249566, 'longitude': -122.033285, 'heading': 0, 'speed': 61.16}
# {'latitude': 37.83917, 'longitude': -122.29196, 'heading': 180, 'speed': 24.38}
# {'latitude': 55.7414, 'longitude': -97.8291, 'heading': 42, 'speed': 0.0}
# {'latitude': 34.832425, 'longitude': -120.56371, 'heading': 135, 'speed': 50.57}
# {'latitude': 34.120484, 'longitude': -118.256009, 'heading': 315, 'speed': 0.0}
# {'latitude': 34.421216, 'longitude': -119.615407, 'heading': 370, 'speed': 50.58}
# {'latitude': 34.061307, 'longitude': -118.231953, 'heading': 225, 'speed': 7.96}
# {'latitude': 33.418912, 'longitude': -117.619282, 'heading': 135, 'speed': 1.52}
# {'latitude': 45.3523, 'longitude': -75.6911, 'heading': 215, 'speed': 36.04}
# {'latitude': 43.9675, 'longitude': -78.1723, 'heading': 64, 'speed': 28.58}

# %%
df_nc = df.query('name in ("Silver Meteor","Carolinian","Piedmont","Palmetto","Crescent")')
df_nc.shape
# Out:
# (12, 16)

# %%
df_nc['current_timezone'].unique()
# Out:
# array(['America/New_York', 'America/Chicago'], dtype=object)

# %%
# Extract latitude and longitude only from valid dictionaries
def extract_coordinates(location):
    if isinstance(location, dict):
        return location.get('latitude'), location.get('longitude'), location.get('speed')
    else:
        return None, None, None

# %%
# %%capture --no-stdout
df_nc[['latitude', 'longitude', 'speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
df_nc.head()

# %%
sdf = GeoAccessor.from_xy(
    df_nc,
    x_column='longitude',
    y_column='latitude'
)

#Create a geodataframe from the data
gdf = gpd.GeoDataFrame(
    data = sdf,
    geometry = 'SHAPE',
    crs = 4326)

# %%
# read in NC boundary to be the clipping gdf (doesn't work, thus commented out)
# nc_boundary = GeoAccessor.from_featureclass("../01_Data/01_Source/NC_Boundary/NCDOT_State_Boundary.shp")
# gdf_nc = gpd.GeoDataFrame(
#     data = nc_boundary,
#     geometry = 'SHAPE',
#     crs = 4326)

# %%
gdf_county = gpd.read_file('../01_Data/01_Source/North_Carolina_State_and_County_Boundary_Polygons.zip').to_crs(gdf.crs)

# %%
gdf_snap_nc = gpd.clip(gdf,gdf_county)

# %%
gdf_snap_nc.head()
# Out:
#               train_id railroad origin_date  number all_numbers      name  \
# 64  2023-11-12_AMTK_74   AMTRAK  2023-11-12      74        [74]  Piedmont
# 65  2023-11-12_AMTK_75   AMTRAK  2023-11-12      75        [75]  Piedmont
# 68  2023-11-12_AMTK_89   AMTRAK  2023-11-12      89        [89]  Palmetto
# 70  2023-11-12_AMTK_90   AMTRAK  2023-11-12      90        [90]  Palmetto
#
#    origin destination  partial_train  last_updated  current_timezone  \
# 64    CLT         RGH          False    1699818117  America/New_York
# 65    RGH         CLT          False    1699818159  America/New_York
# 68    NYP         SAV          False    1699818057  America/New_York
# 70    SAV         NYP          False    1699818145  America/New_York
#
#     threshold  disruption  total_miles  \
# 64         10       False          173
# 65         10       False          173
# 68         30       False          830
# 70         30       False          830
#
#                                              location  \
# 64  {'latitude': 35.439048, 'longitude': -80.60831...
# 65  {'latitude': 36.089347, 'longitude': -79.69185...
# 68  {'latitude': 35.867607, 'longitude': -77.82821...
# 70  {'latitude': 35.873291, 'longitude': -77.82513...
#
#                                                 stops   latitude  longitude  \
# 64  [{'code': 'CLT', 'miles': 0, 'sched_depart': 1...  35.439048 -80.608310
# 65  [{'code': 'RGH', 'miles': 0, 'sched_depart': 1...  36.089347 -79.691852
# 68  [{'code': 'NYP', 'miles': 0, 'sched_depart': 1...  35.867607 -77.828211
# 70  [{'code': 'SAV', 'miles': 0, 'sched_depart': 1...  35.873291 -77.825137
#
#                          SHAPE
# 64  POINT (-80.60831 35.43905)
# 65  POINT (-79.69185 36.08935)
# 68  POINT (-77.82821 35.86761)
# 70  POINT (-77.82514 35.87329)

# %%
#Plot them with a base map
status_plot = gdf_snap_nc.to_crs(3857).plot()
ctx.add_basemap(status_plot)

# %%
# import os
# import pandas as pd
# import geopandas as gpd
# from arcgis import GeoAccessor
# %%capture --no-stdout  #snooze the warning

# Define the folder path where JSON files are located
json_folder = '../01_Data/01_Source/ASM'

# Define the function to extract the lng, la, and speed only from valid dictionaries
def extract_coordinates(location):
    if isinstance(location, dict):
        return location.get('latitude'), location.get('longitude'), location.get('speed')
    else:
        return None, None, None

# Initialize an empty GeoDataFrame to store the combined data
gdf_realop = gpd.GeoDataFrame()

# Read and process each JSON file in the folder
for filename in os.listdir(json_folder):
    if filename.endswith('.json'):
        json_filepath = os.path.join(json_folder, filename)
        
        # Read JSON file into a df
        df = pd.read_json(json_filepath)
        
        # Filter routes that pass nc and make lng, lat, speed to independent columns
        df_nc = df.query('name in ("Silver Meteor","Carolinian","Piedmont","Palmetto","Crescent")')
        df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
        
        # Create a sdf
        sdf = GeoAccessor.from_xy(df_nc, x_column='longitude', y_column='latitude')
        
        # Create a gdf
        gdf = gpd.GeoDataFrame(data=sdf, geometry='SHAPE', crs=4326)
        
        # Clip the GeoDataFrame to the county boundary
        gdf_snap_nc = gpd.clip(gdf, gdf_county)
        
        # Append the clipped gdf to the combined gdf
        gdf_realop = gdf_realop.append(gdf_snap_nc, ignore_index=True)

# Remove duplicates based on name and location
gdf_realop = gdf_realop.drop_duplicates(subset=['name', 'last_updated','latitude', 'longitude',])

gdf_realop.head()
# Out:
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nc[['latitude', 'longitude','speed']] = df_nc['location'].apply(extract_coordinates).apply(pd.Series)
# C:\Users\ct325\AppData\Local\Temp\ipykernel_10844\4034811942.py:34: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_gdf = combined_gdf.append(gdf_snap_nc, ignore_index=True)
#               train_id railroad origin_date  number all_numbers      name  \
# 0   2023-11-12_AMTK_74   AMTRAK  2023-11-12      74        [74]  Piedmont
# 1   2023-11-12_AMTK_75   AMTRAK  2023-11-12      75        [75]  Piedmont
# 2   2023-11-12_AMTK_89   AMTRAK  2023-11-12      89        [89]  Palmetto
# 3   2023-11-12_AMTK_90   AMTRAK  2023-11-12      90        [90]  Palmetto
# 28  2023-11-12_AMTK_74   AMTRAK  2023-11-12      74        [74]  Piedmont
#
#    origin destination  partial_train  last_updated  current_timezone  \
# 0     CLT         RGH          False    1699818117  America/New_York
# 1     RGH         CLT          False    1699818159  America/New_York
# 2     NYP         SAV          False    1699818057  America/New_York
# 3     SAV         NYP          False    1699818145  America/New_York
# 28    CLT         RGH          False    1699818337  America/New_York
#
#     threshold  disruption  total_miles  \
# 0          10       False          173
# 1          10       False          173
# 2          30       False          830
# 3          30       False          830
# 28         10       False          173
#
#                                              location  \
# 0   {'latitude': 35.439048, 'longitude': -80.60831...
# 1   {'latitude': 36.089347, 'longitude': -79.69185...
# 2   {'latitude': 35.867607, 'longitude': -77.82821...
# 3   {'latitude': 35.873291, 'longitude': -77.82513...
# 28  {'latitude': 35.495498, 'longitude': -80.62470...
#
#                                                 stops   latitude  longitude  \
# 0   [{'code': 'CLT', 'miles': 0, 'sched_depart': 1...  35.439048 -80.608310
# 1   [{'code': 'RGH', 'miles': 0, 'sched_depart': 1...  36.089347 -79.691852
# 2   [{'code': 'NYP', 'miles': 0, 'sched_depart': 1...  35.867607 -77.828211
# 3   [{'code': 'SAV', 'miles': 0, 'sched_depart': 1...  35.873291 -77.825137
# 28  [{'code': 'CLT', 'miles': 0, 'sched_depart': 1...  35.495498 -80.624706
#
#     speed                       SHAPE
# 0   75.62  POINT (-80.60831 35.43905)
# 1   51.49  POINT (-79.69185 36.08935)
# 2   69.97  POINT (-77.82821 35.86761)
# 3   70.18  POINT (-77.82514 35.87329)
# 28   0.02  POINT (-80.62471 35.49550)

# %%
gdf_realop.shape
# Out:
# (169, 20)

# %%
gdf_realop = gdf_realop.set_geometry('SHAPE')

# %%
#Plot them with a base map
realop_plot = gdf_realop.to_crs(3857).plot(column='speed')
ctx.add_basemap(realop_plot)

# %%
#Export the geodataframe to a CSV file
pd.DataFrame(gdf_realop).to_csv(
    '../01_data/02_Processed/realopNov12.csv',
    index=False
)
